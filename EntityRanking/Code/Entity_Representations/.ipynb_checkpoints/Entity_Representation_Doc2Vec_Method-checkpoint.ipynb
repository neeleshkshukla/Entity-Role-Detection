# %% [markdown]
# This implementation
#
# 1. Reads the entity word and context word stored in doc_entity_context_word.p dictionary
#
# Dictionary format
#
# Element of Dictionary [ doc_id: dictonary of roles]
#
# Key: Document names present in the corpus
# Values: Dictionary of roles present in specific directory
#
# Elements of Role Dictionary:
# Keys: Roles present in a specific doc
# Value: List of entities having that role
#
# Entity list itself is a list of words
#
#
# 2. Train the Doc2Vec model Store the trained model
# 3. Generate Doc2Vec representation for Entities at Sentence Level
# 4. Generate Doc2Vec representation for Entities at Doc Level
#
# Dictionary format
#
# Element of Dictionary [ doc_id: dictonary of roles]
#
# Key: Document names present in the corpus
# Values: Dictionary of roles present in specific directory
#
# Elements of Role Dictionary:
# Keys: Roles present in a specific doc
# Value: List of entities having that role
#
# Entity in the Entity list is 300-d vector which is doc2vec

# %%
import os, pickle
import gensim, logging
from gensim.models import Word2Vec, Phrases, phrases, KeyedVectors, doc2vec
import scipy, numpy


logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
data_output_folder = '../../Data/output'
train_entity_rep_output_folder = 'EntityRep/train'
test_entity_rep_output_folder = 'EntityRep/test'
entity_context_word_file = 'doc_entity_context_word.p'
entity_doc_level_context_word_file = 'doc_entity_doc_Level_context_word.p'

doc_level = True
sent_level = False

word_emnbedding_pretrained_trained_on_corpus = '../../trained_word_embeddings/word2vec/word_pretrain_trained_on_corpus/w2v_pretain_corpus_trained_gensim_300.txt'

# %%
# Load the pickle file

if sent_level:
    train_doc_role_entity_context_word_dict = pickle.load(open(os.path.join(data_output_folder, train_entity_rep_output_folder, entity_context_word_file), 'rb'))
    test_doc_role_entity_context_word_dict = pickle.load(open(os.path.join(data_output_folder, test_entity_rep_output_folder, entity_context_word_file), 'rb'))
    
if doc_level:
    train_doc_role_entity_context_word_dict = pickle.load(open(os.path.join(data_output_folder, train_entity_rep_output_folder, entity_doc_level_context_word_file), 'rb'))
    test_doc_role_entity_context_word_dict = pickle.load(open(os.path.join(data_output_folder, test_entity_rep_output_folder, entity_doc_level_context_word_file), 'rb'))

# %%
word_vectors = KeyedVectors.load_word2vec_format(word_emnbedding_pretrained_trained_on_corpus, binary=False)
# Out:
# 2018-05-11 03:15:30,175 : INFO : loading projection weights from ../../trained_word_embeddings/word2vec/word_pretrain_trained_on_corpus/w2v_pretain_corpus_trained_gensim_300.txt
# 2018-05-11 03:17:33,571 : INFO : loaded (408497, 300) matrix from ../../trained_word_embeddings/word2vec/word_pretrain_trained_on_corpus/w2v_pretain_corpus_trained_gensim_300.txt

# %%
def read_entities_build_corpus(doc_role_entity_context_word_dict, tokens_only=False):
    entities_corpus = list()
    
    for doc in doc_role_entity_context_word_dict.keys():
       
        tag_dict = doc_role_entity_context_word_dict[doc]
        
        for tag in tag_dict.keys():
            entity_list = tag_dict[tag]
            for entity in entity_list:
                if tokens_only:
                    yield(entity[1])
                else:
                    yield doc2vec.TaggedDocument(entity[1], [doc+'_'+entity[0]])

# %%
train_corpus = list(read_entities_build_corpus(train_doc_role_entity_context_word_dict))
train_corpus[:2]
# Out:
# [TaggedDocument(words=[',', 'coming', 'on', 'a', 'bicycle', 'and', 'parking', 'it', 'opposite', 'the', 'Sai', 'Service', 'petrol', 'pump', '.', 'The', 'bomb', ',', 'which', 'was', 'placed', 'in', 'a', 'basket'], tags=['ev_088_st_003.txt_Sai_Service_petrol_pump']),
#  TaggedDocument(words=['.', 'His', 'image', 'was', 'also', 'captured', 'on', 'CCTV', 'at', 'the', 'German', 'Bakery', 'on', 'February', '13', ',', '2010', '.', 'Sources', 'said', 'the', 'investigators'], tags=['ev_088_st_003.txt_German_Bakery'])]

# %%
test_corpus = list(read_entities_build_corpus(test_doc_role_entity_context_word_dict, tokens_only=True))
print(test_corpus[:2])
# Out:
# [['serial', 'blasts', 'were', 'the', 'handiwork', 'of', 'Indian', 'Mujahideen', 'to', 'avenge', 'Muzaffarnagar', 'riots', '?', 'That', "'s", 'what', 'the', 'security', 'agencies', 'want', 'us'], [',', 'scare', 'people', 'and', 'scuttle', 'the', 'rally', '.', 'Not', 'avenging', 'Muzaffarnagar', 'as', 'the', 'police', 'is', 'spinning', 'it.Bihar', ',', 'Patna', 'or', 'for']]

# %% [markdown]
# #### Train the model with pretrained word2vec

# %%
model = doc2vec.Doc2Vec(vector_size=300, min_count=1, epochs=100, pretrained_emb=word_emnbedding_pretrained_trained_on_corpus)
model.build_vocab(train_corpus)
#training_examples_count = model.corpus_count
#model.build_vocab([list(word_vectors.vocab.keys())], update=True)

#model.intersect_word2vec_format(word_emnbedding_pretrained_trained_on_corpus,binary=False, lockf=1.0)
# Out:
# 2018-05-11 03:17:48,799 : INFO : collecting all words and their counts
# 2018-05-11 03:17:48,802 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-05-11 03:17:48,944 : INFO : PROGRESS: at example #10000, processed 211600 words (1510428/s), 10807 word types, 6998 tags
# 2018-05-11 03:17:49,038 : INFO : collected 15561 word types and 13383 unique tags from a corpus of 19366 examples and 410293 words
# 2018-05-11 03:17:49,040 : INFO : Loading a fresh vocabulary
# 2018-05-11 03:17:49,088 : INFO : min_count=1 retains 15561 unique words (100% of original 15561, drops 0)
# 2018-05-11 03:17:49,089 : INFO : min_count=1 leaves 410293 word corpus (100% of original 410293, drops 0)
# 2018-05-11 03:17:49,172 : INFO : deleting the raw counts dictionary of 15561 items
# 2018-05-11 03:17:49,174 : INFO : sample=0.001 downsamples 39 most-common words
# 2018-05-11 03:17:49,175 : INFO : downsampling leaves estimated 301757 word corpus (73.5% of prior 410293)
# 2018-05-11 03:17:49,251 : INFO : estimated required memory for 15561 words and 300 dimensions: 63863100 bytes
# 2018-05-11 03:17:49,253 : INFO : resetting layer weights

# %%
# %time model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# 2018-05-11 03:18:21,676 : INFO : training model with 3 workers on 15561 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-05-11 03:18:22,841 : INFO : EPOCH 1 - PROGRESS: at 70.67% examples, 224963 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:23,153 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:23,179 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:23,205 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:23,206 : INFO : EPOCH - 1 : training on 410293 raw words (321456 effective words) took 1.4s, 233987 effective words/s
# 2018-05-11 03:18:24,226 : INFO : EPOCH 2 - PROGRESS: at 75.56% examples, 239926 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:24,507 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:24,512 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:24,541 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:24,542 : INFO : EPOCH - 2 : training on 410293 raw words (321056 effective words) took 1.3s, 242208 effective words/s
# 2018-05-11 03:18:25,573 : INFO : EPOCH 3 - PROGRESS: at 75.56% examples, 236709 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:25,820 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:25,837 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:25,882 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:25,883 : INFO : EPOCH - 3 : training on 410293 raw words (321178 effective words) took 1.3s, 240841 effective words/s
# 2018-05-11 03:18:26,933 : INFO : EPOCH 4 - PROGRESS: at 75.56% examples, 231835 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:27,184 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:27,235 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:27,242 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:27,242 : INFO : EPOCH - 4 : training on 410293 raw words (320865 effective words) took 1.4s, 237211 effective words/s
# 2018-05-11 03:18:28,264 : INFO : EPOCH 5 - PROGRESS: at 75.56% examples, 238831 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:28,543 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:28,552 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:28,556 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:28,557 : INFO : EPOCH - 5 : training on 410293 raw words (321177 effective words) took 1.3s, 245517 effective words/s
# 2018-05-11 03:18:29,569 : INFO : EPOCH 6 - PROGRESS: at 73.11% examples, 234385 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:29,863 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:29,877 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:29,896 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:29,897 : INFO : EPOCH - 6 : training on 410293 raw words (321088 effective words) took 1.3s, 241777 effective words/s
# 2018-05-11 03:18:30,919 : INFO : EPOCH 7 - PROGRESS: at 75.55% examples, 238642 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:31,187 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:31,203 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:31,229 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:31,230 : INFO : EPOCH - 7 : training on 410293 raw words (321342 effective words) took 1.3s, 242144 effective words/s
# 2018-05-11 03:18:32,260 : INFO : EPOCH 8 - PROGRESS: at 75.56% examples, 237747 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:32,532 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:32,535 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:32,552 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:32,554 : INFO : EPOCH - 8 : training on 410293 raw words (321173 effective words) took 1.3s, 244487 effective words/s
# 2018-05-11 03:18:33,573 : INFO : EPOCH 9 - PROGRESS: at 75.56% examples, 240575 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:33,886 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:33,904 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:33,927 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:33,931 : INFO : EPOCH - 9 : training on 410293 raw words (321127 effective words) took 1.4s, 235161 effective words/s
# 2018-05-11 03:18:34,942 : INFO : EPOCH 10 - PROGRESS: at 63.37% examples, 203143 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:35,423 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:35,487 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:35,493 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:35,494 : INFO : EPOCH - 10 : training on 410293 raw words (321183 effective words) took 1.6s, 206871 effective words/s
# 2018-05-11 03:18:36,516 : INFO : EPOCH 11 - PROGRESS: at 75.56% examples, 238992 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:36,778 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:36,809 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:36,830 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:36,831 : INFO : EPOCH - 11 : training on 410293 raw words (320722 effective words) took 1.3s, 241738 effective words/s
# 2018-05-11 03:18:37,861 : INFO : EPOCH 12 - PROGRESS: at 75.56% examples, 237144 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:38,120 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:38,160 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:38,165 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:38,166 : INFO : EPOCH - 12 : training on 410293 raw words (320855 effective words) took 1.3s, 241955 effective words/s
# 2018-05-11 03:18:39,234 : INFO : EPOCH 13 - PROGRESS: at 77.98% examples, 236024 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:39,472 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:39,480 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:39,495 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:39,496 : INFO : EPOCH - 13 : training on 410293 raw words (321047 effective words) took 1.3s, 243113 effective words/s
# 2018-05-11 03:18:40,556 : INFO : EPOCH 14 - PROGRESS: at 77.99% examples, 237742 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:40,775 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:40,810 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:40,836 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:40,837 : INFO : EPOCH - 14 : training on 410293 raw words (321058 effective words) took 1.3s, 241000 effective words/s
# 2018-05-11 03:18:41,856 : INFO : EPOCH 15 - PROGRESS: at 75.56% examples, 239730 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:42,126 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:42,131 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:42,181 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:42,182 : INFO : EPOCH - 15 : training on 410293 raw words (321293 effective words) took 1.3s, 240232 effective words/s
# 2018-05-11 03:18:43,203 : INFO : EPOCH 16 - PROGRESS: at 75.56% examples, 239437 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:43,448 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:43,506 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:43,517 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:43,518 : INFO : EPOCH - 16 : training on 410293 raw words (321085 effective words) took 1.3s, 241966 effective words/s
# 2018-05-11 03:18:44,528 : INFO : EPOCH 17 - PROGRESS: at 73.11% examples, 233824 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:44,804 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:44,842 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:44,860 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:44,861 : INFO : EPOCH - 17 : training on 410293 raw words (320837 effective words) took 1.3s, 240358 effective words/s
# 2018-05-11 03:18:45,940 : INFO : EPOCH 18 - PROGRESS: at 77.98% examples, 233286 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:46,156 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:46,163 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:46,202 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:46,203 : INFO : EPOCH - 18 : training on 410293 raw words (320889 effective words) took 1.3s, 240431 effective words/s
# 2018-05-11 03:18:47,250 : INFO : EPOCH 19 - PROGRESS: at 77.98% examples, 240398 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:47,474 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:47,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:47,510 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:47,511 : INFO : EPOCH - 19 : training on 410293 raw words (321107 effective words) took 1.3s, 246959 effective words/s
# 2018-05-11 03:18:48,536 : INFO : EPOCH 20 - PROGRESS: at 75.56% examples, 238274 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:48,768 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:48,793 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:48,816 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:48,817 : INFO : EPOCH - 20 : training on 410293 raw words (321158 effective words) took 1.3s, 247358 effective words/s
# 2018-05-11 03:18:49,895 : INFO : EPOCH 21 - PROGRESS: at 77.99% examples, 235948 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:50,098 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:50,102 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:50,143 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:50,144 : INFO : EPOCH - 21 : training on 410293 raw words (321191 effective words) took 1.3s, 245376 effective words/s
# 2018-05-11 03:18:51,181 : INFO : EPOCH 22 - PROGRESS: at 77.99% examples, 243176 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:51,398 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:51,432 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:51,452 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:51,453 : INFO : EPOCH - 22 : training on 410293 raw words (321205 effective words) took 1.3s, 247035 effective words/s
# 2018-05-11 03:18:52,461 : INFO : EPOCH 23 - PROGRESS: at 75.56% examples, 241469 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:52,724 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:52,729 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:52,753 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:52,754 : INFO : EPOCH - 23 : training on 410293 raw words (320873 effective words) took 1.3s, 247856 effective words/s
# 2018-05-11 03:18:53,774 : INFO : EPOCH 24 - PROGRESS: at 75.56% examples, 238945 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:53,999 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:54,055 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:54,066 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:54,067 : INFO : EPOCH - 24 : training on 410293 raw words (320934 effective words) took 1.3s, 245670 effective words/s
# 2018-05-11 03:18:55,120 : INFO : EPOCH 25 - PROGRESS: at 77.98% examples, 238835 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:55,349 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:55,353 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:55,392 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:55,393 : INFO : EPOCH - 25 : training on 410293 raw words (320930 effective words) took 1.3s, 243366 effective words/s
# 2018-05-11 03:18:56,407 : INFO : EPOCH 26 - PROGRESS: at 75.55% examples, 240894 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:56,632 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:56,677 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:56,695 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:56,696 : INFO : EPOCH - 26 : training on 410293 raw words (321089 effective words) took 1.3s, 248045 effective words/s
# 2018-05-11 03:18:57,717 : INFO : EPOCH 27 - PROGRESS: at 75.56% examples, 239373 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:18:57,962 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:57,992 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:58,004 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:58,005 : INFO : EPOCH - 27 : training on 410293 raw words (321429 effective words) took 1.3s, 247066 effective words/s
# 2018-05-11 03:18:59,032 : INFO : EPOCH 28 - PROGRESS: at 75.56% examples, 238283 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:18:59,275 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:18:59,301 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:18:59,316 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:18:59,317 : INFO : EPOCH - 28 : training on 410293 raw words (321309 effective words) took 1.3s, 246659 effective words/s
# 2018-05-11 03:19:00,330 : INFO : EPOCH 29 - PROGRESS: at 73.11% examples, 233147 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:00,603 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:00,610 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:00,638 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:00,639 : INFO : EPOCH - 29 : training on 410293 raw words (320920 effective words) took 1.3s, 244167 effective words/s
# 2018-05-11 03:19:01,705 : INFO : EPOCH 30 - PROGRESS: at 77.98% examples, 236837 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:01,904 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:01,947 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:01,953 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:01,954 : INFO : EPOCH - 30 : training on 410293 raw words (320811 effective words) took 1.3s, 246133 effective words/s
# 2018-05-11 03:19:02,970 : INFO : EPOCH 31 - PROGRESS: at 75.56% examples, 239963 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:03,211 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:03,231 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:03,269 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:03,270 : INFO : EPOCH - 31 : training on 410293 raw words (321088 effective words) took 1.3s, 245236 effective words/s
# 2018-05-11 03:19:04,284 : INFO : EPOCH 32 - PROGRESS: at 77.99% examples, 249143 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:04,539 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:04,557 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:04,575 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:04,576 : INFO : EPOCH - 32 : training on 410293 raw words (321221 effective words) took 1.3s, 247949 effective words/s
# 2018-05-11 03:19:05,630 : INFO : EPOCH 33 - PROGRESS: at 70.67% examples, 216974 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:05,969 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:05,982 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:05,995 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:05,995 : INFO : EPOCH - 33 : training on 410293 raw words (321359 effective words) took 1.4s, 227633 effective words/s
# 2018-05-11 03:19:07,029 : INFO : EPOCH 34 - PROGRESS: at 73.11% examples, 228497 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:07,325 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:07,331 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:07,357 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:07,358 : INFO : EPOCH - 34 : training on 410293 raw words (321239 effective words) took 1.4s, 237077 effective words/s
# 2018-05-11 03:19:08,391 : INFO : EPOCH 35 - PROGRESS: at 68.24% examples, 213040 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:08,776 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:08,825 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:08,836 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:08,836 : INFO : EPOCH - 35 : training on 410293 raw words (321229 effective words) took 1.5s, 218211 effective words/s
# 2018-05-11 03:19:09,880 : INFO : EPOCH 36 - PROGRESS: at 70.67% examples, 218550 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:10,250 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:10,290 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:10,312 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:10,313 : INFO : EPOCH - 36 : training on 410293 raw words (320912 effective words) took 1.5s, 218464 effective words/s
# 2018-05-11 03:19:11,326 : INFO : EPOCH 37 - PROGRESS: at 75.56% examples, 241459 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:11,608 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:11,615 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:11,670 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:11,670 : INFO : EPOCH - 37 : training on 410293 raw words (321167 effective words) took 1.3s, 238330 effective words/s
# 2018-05-11 03:19:12,699 : INFO : EPOCH 38 - PROGRESS: at 70.67% examples, 222244 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:13,078 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:13,087 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:13,118 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:13,118 : INFO : EPOCH - 38 : training on 410293 raw words (320790 effective words) took 1.4s, 222954 effective words/s
# 2018-05-11 03:19:14,147 : INFO : EPOCH 39 - PROGRESS: at 75.56% examples, 238755 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:14,396 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:14,417 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:14,452 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:14,453 : INFO : EPOCH - 39 : training on 410293 raw words (321231 effective words) took 1.3s, 243217 effective words/s
# 2018-05-11 03:19:15,486 : INFO : EPOCH 40 - PROGRESS: at 77.99% examples, 245224 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:15,746 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:15,749 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:15,765 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:15,766 : INFO : EPOCH - 40 : training on 410293 raw words (320903 effective words) took 1.3s, 247047 effective words/s
# 2018-05-11 03:19:16,824 : INFO : EPOCH 41 - PROGRESS: at 77.99% examples, 238844 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:17,046 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:17,073 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:17,084 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:17,085 : INFO : EPOCH - 41 : training on 410293 raw words (320948 effective words) took 1.3s, 245696 effective words/s
# 2018-05-11 03:19:18,109 : INFO : EPOCH 42 - PROGRESS: at 75.56% examples, 238468 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:18,387 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:18,406 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:18,416 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:18,418 : INFO : EPOCH - 42 : training on 410293 raw words (321092 effective words) took 1.3s, 242401 effective words/s
# 2018-05-11 03:19:19,435 : INFO : EPOCH 43 - PROGRESS: at 75.56% examples, 240626 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:19,716 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:19,717 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:19,731 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:19,732 : INFO : EPOCH - 43 : training on 410293 raw words (321222 effective words) took 1.3s, 246293 effective words/s
# 2018-05-11 03:19:20,745 : INFO : EPOCH 44 - PROGRESS: at 73.11% examples, 234195 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:21,027 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:21,035 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:21,052 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:21,053 : INFO : EPOCH - 44 : training on 410293 raw words (321089 effective words) took 1.3s, 245353 effective words/s
# 2018-05-11 03:19:22,092 : INFO : EPOCH 45 - PROGRESS: at 75.56% examples, 237105 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:22,327 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:22,334 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:22,387 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:22,388 : INFO : EPOCH - 45 : training on 410293 raw words (320927 effective words) took 1.3s, 243849 effective words/s
# 2018-05-11 03:19:23,468 : INFO : EPOCH 46 - PROGRESS: at 77.99% examples, 233632 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:23,678 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:23,682 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:23,713 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:23,714 : INFO : EPOCH - 46 : training on 410293 raw words (321105 effective words) took 1.3s, 243989 effective words/s
# 2018-05-11 03:19:24,724 : INFO : EPOCH 47 - PROGRESS: at 75.56% examples, 242015 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:25,006 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:25,033 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:25,044 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:25,045 : INFO : EPOCH - 47 : training on 410293 raw words (321137 effective words) took 1.3s, 242854 effective words/s
# 2018-05-11 03:19:26,091 : INFO : EPOCH 48 - PROGRESS: at 75.56% examples, 233315 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:26,338 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:26,368 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:26,387 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:26,388 : INFO : EPOCH - 48 : training on 410293 raw words (321042 effective words) took 1.3s, 240502 effective words/s
# 2018-05-11 03:19:27,408 : INFO : EPOCH 49 - PROGRESS: at 75.56% examples, 239428 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:27,641 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:27,679 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:27,685 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:27,686 : INFO : EPOCH - 49 : training on 410293 raw words (321053 effective words) took 1.3s, 249114 effective words/s
# 2018-05-11 03:19:28,719 : INFO : EPOCH 50 - PROGRESS: at 75.55% examples, 236430 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:28,960 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:28,980 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:28,999 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:28,999 : INFO : EPOCH - 50 : training on 410293 raw words (321163 effective words) took 1.3s, 246046 effective words/s
# 2018-05-11 03:19:30,026 : INFO : EPOCH 51 - PROGRESS: at 75.56% examples, 237695 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:30,277 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:30,296 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:30,317 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:30,318 : INFO : EPOCH - 51 : training on 410293 raw words (320964 effective words) took 1.3s, 244987 effective words/s
# 2018-05-11 03:19:31,339 : INFO : EPOCH 52 - PROGRESS: at 75.56% examples, 238786 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:31,600 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:31,613 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:31,631 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:31,632 : INFO : EPOCH - 52 : training on 410293 raw words (320790 effective words) took 1.3s, 245492 effective words/s
# 2018-05-11 03:19:32,677 : INFO : EPOCH 53 - PROGRESS: at 77.99% examples, 241293 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:32,890 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:32,901 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:32,941 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:32,942 : INFO : EPOCH - 53 : training on 410293 raw words (321552 effective words) took 1.3s, 246919 effective words/s
# 2018-05-11 03:19:33,980 : INFO : EPOCH 54 - PROGRESS: at 75.55% examples, 234777 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:34,222 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:34,225 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:34,270 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:34,271 : INFO : EPOCH - 54 : training on 410293 raw words (321271 effective words) took 1.3s, 242819 effective words/s
# 2018-05-11 03:19:35,297 : INFO : EPOCH 55 - PROGRESS: at 75.55% examples, 237730 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:35,528 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:35,553 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:35,575 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:35,576 : INFO : EPOCH - 55 : training on 410293 raw words (320969 effective words) took 1.3s, 247432 effective words/s
# 2018-05-11 03:19:36,628 : INFO : EPOCH 56 - PROGRESS: at 77.99% examples, 239892 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:36,858 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:36,875 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:36,880 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:36,882 : INFO : EPOCH - 56 : training on 410293 raw words (321069 effective words) took 1.3s, 247704 effective words/s
# 2018-05-11 03:19:37,895 : INFO : EPOCH 57 - PROGRESS: at 75.56% examples, 241468 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:38,174 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:38,186 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:38,194 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:38,195 : INFO : EPOCH - 57 : training on 410293 raw words (321105 effective words) took 1.3s, 246367 effective words/s
# 2018-05-11 03:19:39,227 : INFO : EPOCH 58 - PROGRESS: at 75.55% examples, 236416 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:39,471 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:39,480 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:39,515 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:39,516 : INFO : EPOCH - 58 : training on 410293 raw words (321124 effective words) took 1.3s, 244447 effective words/s
# 2018-05-11 03:19:40,527 : INFO : EPOCH 59 - PROGRESS: at 75.56% examples, 241858 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:40,780 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:40,817 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:40,823 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:40,824 : INFO : EPOCH - 59 : training on 410293 raw words (321237 effective words) took 1.3s, 247284 effective words/s
# 2018-05-11 03:19:41,862 : INFO : EPOCH 60 - PROGRESS: at 77.99% examples, 242432 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:42,087 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:42,101 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:42,127 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:42,127 : INFO : EPOCH - 60 : training on 410293 raw words (320626 effective words) took 1.3s, 247493 effective words/s
# 2018-05-11 03:19:43,150 : INFO : EPOCH 61 - PROGRESS: at 75.56% examples, 238832 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:43,416 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:43,424 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:43,427 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:43,428 : INFO : EPOCH - 61 : training on 410293 raw words (321275 effective words) took 1.3s, 248588 effective words/s
# 2018-05-11 03:19:44,459 : INFO : EPOCH 62 - PROGRESS: at 75.56% examples, 236537 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:44,699 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:44,701 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:44,749 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:44,750 : INFO : EPOCH - 62 : training on 410293 raw words (320928 effective words) took 1.3s, 244087 effective words/s
# 2018-05-11 03:19:45,787 : INFO : EPOCH 63 - PROGRESS: at 75.55% examples, 235077 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:46,039 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:46,054 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:46,061 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:46,062 : INFO : EPOCH - 63 : training on 410293 raw words (321022 effective words) took 1.3s, 246074 effective words/s
# 2018-05-11 03:19:47,071 : INFO : EPOCH 64 - PROGRESS: at 75.56% examples, 241459 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:47,319 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:47,348 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:47,360 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:47,361 : INFO : EPOCH - 64 : training on 410293 raw words (320941 effective words) took 1.3s, 248379 effective words/s
# 2018-05-11 03:19:48,376 : INFO : EPOCH 65 - PROGRESS: at 75.56% examples, 240380 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:48,626 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:48,655 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:48,663 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:48,664 : INFO : EPOCH - 65 : training on 410293 raw words (321021 effective words) took 1.3s, 247835 effective words/s
# 2018-05-11 03:19:49,691 : INFO : EPOCH 66 - PROGRESS: at 75.56% examples, 238299 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:49,904 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:49,953 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:49,962 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:49,963 : INFO : EPOCH - 66 : training on 410293 raw words (321424 effective words) took 1.3s, 249341 effective words/s
# 2018-05-11 03:19:51,034 : INFO : EPOCH 67 - PROGRESS: at 77.99% examples, 235333 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:19:51,236 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:51,243 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:51,282 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:51,282 : INFO : EPOCH - 67 : training on 410293 raw words (321140 effective words) took 1.3s, 244974 effective words/s
# 2018-05-11 03:19:52,335 : INFO : EPOCH 68 - PROGRESS: at 77.99% examples, 239272 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:52,532 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:52,564 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:52,586 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:52,586 : INFO : EPOCH - 68 : training on 410293 raw words (320951 effective words) took 1.3s, 247725 effective words/s
# 2018-05-11 03:19:53,624 : INFO : EPOCH 69 - PROGRESS: at 77.99% examples, 243003 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:53,833 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:53,877 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:53,888 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:53,888 : INFO : EPOCH - 69 : training on 410293 raw words (321148 effective words) took 1.3s, 248076 effective words/s
# 2018-05-11 03:19:54,899 : INFO : EPOCH 70 - PROGRESS: at 75.56% examples, 241981 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:55,177 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:55,179 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:55,214 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:55,215 : INFO : EPOCH - 70 : training on 410293 raw words (321111 effective words) took 1.3s, 243808 effective words/s
# 2018-05-11 03:19:56,245 : INFO : EPOCH 71 - PROGRESS: at 75.56% examples, 237996 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:56,499 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:56,508 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:56,523 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:56,524 : INFO : EPOCH - 71 : training on 410293 raw words (321426 effective words) took 1.3s, 247603 effective words/s
# 2018-05-11 03:19:57,599 : INFO : EPOCH 72 - PROGRESS: at 77.98% examples, 234364 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:57,805 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:57,819 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:57,834 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:57,836 : INFO : EPOCH - 72 : training on 410293 raw words (321211 effective words) took 1.3s, 246309 effective words/s
# 2018-05-11 03:19:58,846 : INFO : EPOCH 73 - PROGRESS: at 75.56% examples, 241442 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:19:59,131 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:19:59,134 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:19:59,145 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:19:59,146 : INFO : EPOCH - 73 : training on 410293 raw words (320866 effective words) took 1.3s, 246349 effective words/s
# 2018-05-11 03:20:00,172 : INFO : EPOCH 74 - PROGRESS: at 75.56% examples, 237969 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:00,412 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:00,449 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:00,454 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:00,455 : INFO : EPOCH - 74 : training on 410293 raw words (320926 effective words) took 1.3s, 246839 effective words/s
# 2018-05-11 03:20:01,471 : INFO : EPOCH 75 - PROGRESS: at 75.55% examples, 240102 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:01,726 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:01,756 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:01,772 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:01,773 : INFO : EPOCH - 75 : training on 410293 raw words (320960 effective words) took 1.3s, 245063 effective words/s
# 2018-05-11 03:20:02,789 : INFO : EPOCH 76 - PROGRESS: at 70.69% examples, 225186 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:03,118 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:03,120 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:03,153 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:03,154 : INFO : EPOCH - 76 : training on 410293 raw words (321398 effective words) took 1.4s, 234230 effective words/s
# 2018-05-11 03:20:04,222 : INFO : EPOCH 77 - PROGRESS: at 77.99% examples, 235948 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:04,417 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:04,425 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:04,467 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:04,467 : INFO : EPOCH - 77 : training on 410293 raw words (321461 effective words) took 1.3s, 246091 effective words/s
# 2018-05-11 03:20:05,484 : INFO : EPOCH 78 - PROGRESS: at 75.56% examples, 239812 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:05,753 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:05,775 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:05,781 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:05,782 : INFO : EPOCH - 78 : training on 410293 raw words (321055 effective words) took 1.3s, 245396 effective words/s
# 2018-05-11 03:20:06,803 : INFO : EPOCH 79 - PROGRESS: at 75.56% examples, 238690 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:07,053 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:07,083 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:07,088 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:07,088 : INFO : EPOCH - 79 : training on 410293 raw words (321182 effective words) took 1.3s, 247099 effective words/s
# 2018-05-11 03:20:08,115 : INFO : EPOCH 80 - PROGRESS: at 75.55% examples, 237870 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:08,359 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:08,377 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:08,403 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:08,404 : INFO : EPOCH - 80 : training on 410293 raw words (321126 effective words) took 1.3s, 245529 effective words/s
# 2018-05-11 03:20:09,413 : INFO : EPOCH 81 - PROGRESS: at 75.56% examples, 242095 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:09,675 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:09,688 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:09,730 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:09,731 : INFO : EPOCH - 81 : training on 410293 raw words (321474 effective words) took 1.3s, 243691 effective words/s
# 2018-05-11 03:20:10,745 : INFO : EPOCH 82 - PROGRESS: at 75.56% examples, 240843 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:10,982 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:11,018 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:11,036 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:11,037 : INFO : EPOCH - 82 : training on 410293 raw words (321137 effective words) took 1.3s, 247379 effective words/s
# 2018-05-11 03:20:12,097 : INFO : EPOCH 83 - PROGRESS: at 77.98% examples, 238052 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:12,309 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:12,316 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:12,350 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:12,351 : INFO : EPOCH - 83 : training on 410293 raw words (321004 effective words) took 1.3s, 246030 effective words/s
# 2018-05-11 03:20:13,368 : INFO : EPOCH 84 - PROGRESS: at 75.56% examples, 240240 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:13,630 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:13,637 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:13,680 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:13,681 : INFO : EPOCH - 84 : training on 410293 raw words (321368 effective words) took 1.3s, 242989 effective words/s
# 2018-05-11 03:20:14,694 : INFO : EPOCH 85 - PROGRESS: at 75.56% examples, 241020 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:14,923 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:14,970 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:14,982 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:14,983 : INFO : EPOCH - 85 : training on 410293 raw words (320831 effective words) took 1.3s, 247877 effective words/s
# 2018-05-11 03:20:16,005 : INFO : EPOCH 86 - PROGRESS: at 75.56% examples, 239502 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:16,251 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:16,277 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:16,288 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:16,289 : INFO : EPOCH - 86 : training on 410293 raw words (321456 effective words) took 1.3s, 247855 effective words/s
# 2018-05-11 03:20:17,352 : INFO : EPOCH 87 - PROGRESS: at 77.98% examples, 237511 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:17,564 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:17,577 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:17,596 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:17,597 : INFO : EPOCH - 87 : training on 410293 raw words (321227 effective words) took 1.3s, 247367 effective words/s
# 2018-05-11 03:20:18,632 : INFO : EPOCH 88 - PROGRESS: at 75.56% examples, 236120 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:18,847 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:18,892 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:18,898 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:18,898 : INFO : EPOCH - 88 : training on 410293 raw words (321484 effective words) took 1.3s, 248538 effective words/s
# 2018-05-11 03:20:19,929 : INFO : EPOCH 89 - PROGRESS: at 75.55% examples, 236610 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:20,155 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:20,183 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:20,203 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:20,204 : INFO : EPOCH - 89 : training on 410293 raw words (321063 effective words) took 1.3s, 247181 effective words/s
# 2018-05-11 03:20:21,273 : INFO : EPOCH 90 - PROGRESS: at 77.99% examples, 236010 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:21,475 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:21,484 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:21,513 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:21,514 : INFO : EPOCH - 90 : training on 410293 raw words (321115 effective words) took 1.3s, 246902 effective words/s
# 2018-05-11 03:20:22,587 : INFO : EPOCH 91 - PROGRESS: at 75.56% examples, 227928 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:22,802 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:22,848 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:22,854 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:22,855 : INFO : EPOCH - 91 : training on 410293 raw words (321284 effective words) took 1.3s, 241336 effective words/s
# 2018-05-11 03:20:23,864 : INFO : EPOCH 92 - PROGRESS: at 75.56% examples, 242179 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:24,114 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:24,118 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:24,167 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:24,168 : INFO : EPOCH - 92 : training on 410293 raw words (321264 effective words) took 1.3s, 246150 effective words/s
# 2018-05-11 03:20:25,183 : INFO : EPOCH 93 - PROGRESS: at 75.56% examples, 240282 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:25,412 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:25,462 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:25,467 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:25,468 : INFO : EPOCH - 93 : training on 410293 raw words (321296 effective words) took 1.3s, 248400 effective words/s
# 2018-05-11 03:20:26,538 : INFO : EPOCH 94 - PROGRESS: at 77.99% examples, 235441 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:26,742 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:26,747 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:26,778 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:26,779 : INFO : EPOCH - 94 : training on 410293 raw words (321310 effective words) took 1.3s, 246631 effective words/s
# 2018-05-11 03:20:27,809 : INFO : EPOCH 95 - PROGRESS: at 73.11% examples, 229024 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:28,097 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:28,123 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:28,124 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:28,126 : INFO : EPOCH - 95 : training on 410293 raw words (321072 effective words) took 1.3s, 239615 effective words/s
# 2018-05-11 03:20:29,144 : INFO : EPOCH 96 - PROGRESS: at 75.56% examples, 239991 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:29,393 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:29,432 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:29,449 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:29,450 : INFO : EPOCH - 96 : training on 410293 raw words (321115 effective words) took 1.3s, 244047 effective words/s
# 2018-05-11 03:20:30,514 : INFO : EPOCH 97 - PROGRESS: at 75.55% examples, 229381 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:30,738 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:30,772 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:30,788 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:30,789 : INFO : EPOCH - 97 : training on 410293 raw words (320878 effective words) took 1.3s, 240994 effective words/s
# 2018-05-11 03:20:31,859 : INFO : EPOCH 98 - PROGRESS: at 77.98% examples, 235869 words/s, in_qsize 6, out_qsize 0
# 2018-05-11 03:20:32,068 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:32,075 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:32,103 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:32,103 : INFO : EPOCH - 98 : training on 410293 raw words (321433 effective words) took 1.3s, 246129 effective words/s
# 2018-05-11 03:20:33,152 : INFO : EPOCH 99 - PROGRESS: at 77.98% examples, 240894 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:33,366 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:33,371 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:33,412 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:33,413 : INFO : EPOCH - 99 : training on 410293 raw words (321387 effective words) took 1.3s, 247240 effective words/s
# 2018-05-11 03:20:34,434 : INFO : EPOCH 100 - PROGRESS: at 75.56% examples, 238710 words/s, in_qsize 5, out_qsize 0
# 2018-05-11 03:20:34,681 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-11 03:20:34,714 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-11 03:20:34,725 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-11 03:20:34,726 : INFO : EPOCH - 100 : training on 410293 raw words (321193 effective words) took 1.3s, 245854 effective words/s
# 2018-05-11 03:20:34,726 : INFO : training on a 41029300 raw words (32111974 effective words) took 133.0s, 241357 effective words/s
# CPU times: user 4min 3s, sys: 21.2 s, total: 4min 24s
# Wall time: 2min 13s

# %%
def build_doc_role_entity_doc2vec_dictionary(doc_role_entity_context_word_dict):
    
    doc_role_entity_context_word_doc2vec_dict = dict()
    
    for doc in doc_role_entity_context_word_dict.keys():
        #print(doc)
        tag_dict = doc_role_entity_context_word_dict[doc]
        tag_doc2vec_dict = dict()
        for tag in tag_dict.keys():
            entity_list = tag_dict[tag]
            entity_doc2vec_list = list()
            for entity in entity_list:
                entity_doc2vec_list.append((entity[0], model.infer_vector(entity[1])))
            tag_doc2vec_dict[tag] = entity_doc2vec_list
        doc_role_entity_context_word_doc2vec_dict[doc] = tag_doc2vec_dict
        
    return doc_role_entity_context_word_doc2vec_dict

# %%
#train_doc_role_entity_context_word_centroid_dict = build_doc_role_entity_centroid_dictionary(train_doc_role_entity_context_word_dict)
test_doc_role_entity_context_word_doc2vec_dict = build_doc_role_entity_doc2vec_dictionary(test_doc_role_entity_context_word_dict)

# %%
if sent_level:
    pickle.dump(test_doc_role_entity_context_word_doc2vec_dict, open('../../Data/output/EntityRep/test/doc_role_entity_context_word_doc2vec_dict.p', 'wb'))

if doc_level:
    pickle.dump(test_doc_role_entity_context_word_doc2vec_dict, open('../../Data/output/EntityRep/test/doc_role_entity_doc_level_context_word_doc2vec_dict.p', 'wb'))
