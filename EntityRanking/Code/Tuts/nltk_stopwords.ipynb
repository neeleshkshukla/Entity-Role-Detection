# %%
from nltk.corpus import stopwords

# %%
stopWords = set(stopwords.words('english'))

# %%
content = ''

for word in stopWords:
    content = content + word + '\n'

with open('stopwords.txt', 'wt') as stopword_file:
    stopword_file.write(content)

# %%
stopWords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  'd',
#  'did',
#  'didn',
#  'do',
#  'does',
#  'doesn',
#  'doing',
#  'don',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  'has',
#  'hasn',
#  'have',
#  'haven',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  'more',
#  'most',
#  'mustn',
#  'my',
#  'myself',
#  'needn',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
# ...
